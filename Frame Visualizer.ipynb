# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import pylab as pl
import importlib
from IPython import display
from lib import util
from copy import deepcopy
# %matplotlib inline
from lib import frame_util as futil
importlib.reload(futil)
# Out:
# <module 'lib.frame_util' from 'C:\\Users\\Alex Lin\\Documents\\CS229\\Project\\cs229_merging\\lib\\frame_util.py'>

# %%
frameDict = futil.LoadDictFromTxt("res/101_trajectories/aug_trajectories-0750am-0805am.txt", 'frame')
futil.AnimateFrames(frameDict)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-fc6a2515cd8b> in <module>()
#       1 frameDict = futil.LoadDictFromTxt("res/101_trajectories/aug_trajectories-0750am-0805am.txt", 'frame')
# ----> 2 futil.AnimateFrames(frameDict)
#
# C:\Users\Alex Lin\Documents\CS229\Project\cs229_merging\lib\frame_util.py in AnimateFrames(frameDict)
#     141     for i in range(int(len(frameDict)/2)):
#     142         curFrame = frameDict[100 + i*5]
# --> 143         plotFrame(curFrame, i)
#     144         plt.clf()
#     145
#
# C:\Users\Alex Lin\Documents\CS229\Project\cs229_merging\lib\frame_util.py in plotFrame(curFrame, fid)
#     146 def plotFrame(curFrame, fid):
#     147     x,y = getFramePoints(curFrame)
# --> 148     plt.plot(y,70 - x, 'ro')
#     149     plt.title("t = " + str(fid))
#     150     plt.axis([0, 2250, 0, 70])
#
# C:\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(*args, **kwargs)
#    3145 @_autogen_docstring(Axes.plot)
#    3146 def plot(*args, **kwargs):
# -> 3147     ax = gca()
#    3148     # allow callers to override the hold state by passing hold=True|False
#    3149     washold = ax.ishold()
#
# C:\Anaconda3\lib\site-packages\matplotlib\pyplot.py in gca(**kwargs)
#     926     matplotlib.figure.Figure.gca : The figure's gca method.
#     927     """
# --> 928     return gcf().gca(**kwargs)
#     929
#     930 # More ways of creating axes:
#
# C:\Anaconda3\lib\site-packages\matplotlib\figure.py in gca(self, **kwargs)
#    1357
#    1358         # no axes found, so create one which spans the figure
# -> 1359         return self.add_subplot(1, 1, 1, **kwargs)
#    1360
#    1361     def sca(self, a):
#
# C:\Anaconda3\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1003                     self._axstack.remove(ax)
#    1004
# -> 1005             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1006
#    1007         self._axstack.add(key, a)
#
# C:\Anaconda3\lib\site-packages\matplotlib\axes\_subplots.py in __init__(self, fig, *args, **kwargs)
#      71
#      72         # _axes_class is set in the subplot_class_factory
# ---> 73         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      74
#      75     def __reduce__(self):
#
# C:\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in __init__(self, fig, rect, axisbg, frameon, sharex, sharey, label, xscale, yscale, **kwargs)
#     518         self._hold = rcParams['axes.hold']
#     519         self._connected = {}  # a dict from events to (id, func)
# --> 520         self.cla()
#     521         # funcs used to format x and y - fall back on major formatters
#     522         self.fmt_xdata = None
#
# C:\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in cla(self)
#     916         yaxis_visible = self.yaxis.get_visible()
#     917
# --> 918         self.xaxis.cla()
#     919         self.yaxis.cla()
#     920         for name, spine in six.iteritems(self.spines):
#
# C:\Anaconda3\lib\site-packages\matplotlib\axis.py in cla(self)
#     740         self._set_artist_props(self.label)
#     741
# --> 742         self.reset_ticks()
#     743
#     744         self.converter = None
#
# C:\Anaconda3\lib\site-packages\matplotlib\axis.py in reset_ticks(self)
#     754         cbook.popall(self.minorTicks)
#     755
# --> 756         self.majorTicks.extend([self._get_tick(major=True)])
#     757         self.minorTicks.extend([self._get_tick(major=False)])
#     758         self._lastNumMajorTicks = 1
#
# C:\Anaconda3\lib\site-packages\matplotlib\axis.py in _get_tick(self, major)
#    1673         else:
#    1674             tick_kw = self._minor_tick_kw
# -> 1675         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1676
#    1677     def _get_label(self):
#
# C:\Anaconda3\lib\site-packages\matplotlib\axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major)
#     150         self.tick1line = self._get_tick1line()
#     151         self.tick2line = self._get_tick2line()
# --> 152         self.gridline = self._get_gridline()
#     153
#     154         self.label1 = self._get_text1()
#
# C:\Anaconda3\lib\site-packages\matplotlib\axis.py in _get_gridline(self)
#     428                           markersize=0)
#     429         l.set_transform(self.axes.get_xaxis_transform(which='grid'))
# --> 430         l.get_path()._interpolation_steps = GRIDLINE_INTERPOLATION_STEPS
#     431         self._set_artist_props(l)
#     432
#
# C:\Anaconda3\lib\site-packages\matplotlib\lines.py in get_path(self)
#     923         """
#     924         if self._invalidy or self._invalidx:
# --> 925             self.recache()
#     926         return self._path
#     927
#
# C:\Anaconda3\lib\site-packages\matplotlib\lines.py in recache(self, always)
#     633
#     634         self._xy = np.empty((len(x), 2), dtype=np.float_)
# --> 635         self._xy[:, 0] = x
#     636         self._xy[:, 1] = y
#     637
#
# KeyboardInterrupt:

# %%
futil.AnimateFrames(frameDict)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-b8500378c50b> in <module>()
# ----> 1 futil.AnimateFrames(frameDict)
#
# C:\Users\Alex Lin\Documents\CS229\Project\cs229_merging\lib\frame_util.py in AnimateFrames(frameDict)
#     140
#     141     for i in range(int(len(frameDict)/2)):
# --> 142         curFrame = frameDict[100 + i*5]
#     143         plotFrame(curFrame, i)
#     144         plt.clf()
#
# KeyError: 9540
